# %% [markdown]
# # Context
# This data set is created only for the learning purpose of the customer segmentation concepts , also known as market basket analysis . I will demonstrate this by using unsupervised ML technique (KMeans Clustering Algorithm) in the simplest form.
#
# # Content
# You are owing a supermarket mall and through membership cards , you have some basic data about your customers like Customer ID, age, gender, annual income and spending score.
# Spending Score is something you assign to the customer based on your defined parameters like customer behavior and purchasing data.
#
# #Problem Statement
# You own the mall and want to understand the customers like who can be easily converge [Target Customers] so that the sense can be given to marketing team and plan the strategy accordingly.

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn import preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Reading and understanding Data

# %%
raw_data = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Mall_Customers.csv')
raw_data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
raw_data.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
data = raw_data.set_index(['CustomerID'])

# %%
mapping = { "Gender" : {"Male":0, "Female":1}} 
data.replace(mapping, inplace=True)

# %%
data.head()
# Out:
#             Gender  Age  Annual Income (k$)  Spending Score (1-100)
# CustomerID
# 1                0   19                  15                      39
# 2                0   21                  15                      81
# 3                1   20                  16                       6
# 4                1   23                  16                      77
# 5                1   31                  17                      40

# %%
data.describe()
# Out:
#            Gender         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean     0.560000   38.850000           60.560000               50.200000
# std      0.497633   13.969007           26.264721               25.823522
# min      0.000000   18.000000           15.000000                1.000000
# 25%      0.000000   28.750000           41.500000               34.750000
# 50%      1.000000   36.000000           61.500000               50.000000
# 75%      1.000000   49.000000           78.000000               73.000000
# max      1.000000   70.000000          137.000000               99.000000

# %%
data.nunique()
# Out:
# Gender                     2
# Age                       51
# Annual Income (k$)        64
# Spending Score (1-100)    84
# dtype: int64

# %% [markdown]
# ### This provides us the number of unique values present in our data

# %%
data.isnull().sum()
# Out:
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# ### This shows we have no null values in our data hence can now move forward with plotting

# %% [markdown]
# # Pair plotting of data

# %%
sns.pairplot(data)

# %% [markdown]
# # Correlation Matrix

# %%
data.corr()
# Out:
#                           Gender       Age  Annual Income (k$)  \
# Gender                  1.000000 -0.060867           -0.056410
# Age                    -0.060867  1.000000           -0.012398
# Annual Income (k$)     -0.056410 -0.012398            1.000000
# Spending Score (1-100)  0.058109 -0.327227            0.009903
#
#                         Spending Score (1-100)
# Gender                                0.058109
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %% [markdown]
# ### Correlation Matrix using Matplotlib

# %%
plt.matshow(data.corr())
plt.colorbar()

# %% [markdown]
# ### Correlation matrix using SNS

# %%
corr = data.corr()
sns.heatmap(corr, cmap='YlGnBu', linewidths='0.1')

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d7305_row0_col0, #T_d7305_row1_col1, #T_d7305_row2_col2, #T_d7305_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d7305_row0_col1 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_d7305_row0_col2, #T_d7305_row1_col0, #T_d7305_row1_col3, #T_d7305_row3_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d7305_row0_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_d7305_row1_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_d7305_row2_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_d7305_row2_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_d7305_row2_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_d7305_row3_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_d7305_row3_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d7305_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gender</th>
#       <th class="col_heading level0 col1" >Age</th>
#       <th class="col_heading level0 col2" >Annual Income (k$)</th>
#       <th class="col_heading level0 col3" >Spending Score (1-100)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7305_level0_row0" class="row_heading level0 row0" >Gender</th>
#       <td id="T_d7305_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d7305_row0_col1" class="data row0 col1" >-0.060867</td>
#       <td id="T_d7305_row0_col2" class="data row0 col2" >-0.056410</td>
#       <td id="T_d7305_row0_col3" class="data row0 col3" >0.058109</td>
#     </tr>
#     <tr>
#       <th id="T_d7305_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_d7305_row1_col0" class="data row1 col0" >-0.060867</td>
#       <td id="T_d7305_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d7305_row1_col2" class="data row1 col2" >-0.012398</td>
#       <td id="T_d7305_row1_col3" class="data row1 col3" >-0.327227</td>
#     </tr>
#     <tr>
#       <th id="T_d7305_level0_row2" class="row_heading level0 row2" >Annual Income (k$)</th>
#       <td id="T_d7305_row2_col0" class="data row2 col0" >-0.056410</td>
#       <td id="T_d7305_row2_col1" class="data row2 col1" >-0.012398</td>
#       <td id="T_d7305_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d7305_row2_col3" class="data row2 col3" >0.009903</td>
#     </tr>
#     <tr>
#       <th id="T_d7305_level0_row3" class="row_heading level0 row3" >Spending Score (1-100)</th>
#       <td id="T_d7305_row3_col0" class="data row3 col0" >0.058109</td>
#       <td id="T_d7305_row3_col1" class="data row3 col1" >-0.327227</td>
#       <td id="T_d7305_row3_col2" class="data row3 col2" >0.009903</td>
#       <td id="T_d7305_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### By looking at Correlation matrix we can see that Age and Spending score are more linearly correlated than any other feature and Annual Income and Spending score are not at all linearly correlated

# %% [markdown]
# # Building Elbow method graph for identifying number of clusters

# %%
## Building The Elbow Method Graph with full data
wcss = []
for i in range(2,10):
    kmeans = KMeans(i)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)
wcss
# Out:
# [212889.44245524303,
#  143391.59236035676,
#  104414.67534220168,
#  75528.58656469136,
#  58348.641363315044,
#  51147.01731797614,
#  44391.82080487078,
#  40621.192057942055]

# %%
plt.plot(range(2,10), wcss)

# %% [markdown]
# ## Silhouette Score for identifying number of clusters

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

sil = []
# Number of clusters in range 2-20
K = range(2, 10)
for n in K:
    algorithm = (KMeans(n_clusters = n) )
    algorithm.fit(data)
    labels = algorithm.labels_
    sil.append(silhouette_score(data, labels, metric = 'euclidean'))

# %%
sil
# Out:
# [0.29307334005502633,
#  0.383798873822341,
#  0.4052954330641215,
#  0.44482259384548795,
#  0.45205475380756527,
#  0.44096462877395787,
#  0.4275788369618678,
#  0.41426657089184404]

# %%
kmeans = KMeans(6)
kmeans.fit(data)
clusters = data.copy()
clusters['prediction'] = kmeans.fit_predict(data)
clusters[:15]
# Out:
#             Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# CustomerID
# 1                0   19                  15                      39
# 2                0   21                  15                      81
# 3                1   20                  16                       6
# 4                1   23                  16                      77
# 5                1   31                  17                      40
# 6                1   22                  17                      76
# 7                1   35                  18                       6
# 8                1   23                  18                      94
# 9                0   64                  19                       3
# 10               1   30                  19                      72
# 11               0   67                  19                      14
# 12               1   35                  19                      99
# 13               1   58                  20                      15
# 14               1   24                  20                      77
# 15               0   37                  20                      13
#
#             prediction
# CustomerID
# 1                    4
# 2                    0
# 3                    4
# 4                    0
# 5                    4
# 6                    0
# 7                    4
# 8                    0
# 9                    4
# 10                   0
# 11                   4
# 12                   0
# 13                   4
# 14                   0
# 15                   4

# %%
kmeans = KMeans(5)
kmeans.fit(data)
clusters = data.copy()
clusters['prediction'] = kmeans.fit_predict(data)
clusters[:15]
# Out:
#             Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# CustomerID
# 1                0   19                  15                      39
# 2                0   21                  15                      81
# 3                1   20                  16                       6
# 4                1   23                  16                      77
# 5                1   31                  17                      40
# 6                1   22                  17                      76
# 7                1   35                  18                       6
# 8                1   23                  18                      94
# 9                0   64                  19                       3
# 10               1   30                  19                      72
# 11               0   67                  19                      14
# 12               1   35                  19                      99
# 13               1   58                  20                      15
# 14               1   24                  20                      77
# 15               0   37                  20                      13
#
#             prediction
# CustomerID
# 1                    4
# 2                    0
# 3                    4
# 4                    0
# 5                    4
# 6                    0
# 7                    4
# 8                    0
# 9                    4
# 10                   0
# 11                   4
# 12                   0
# 13                   4
# 14                   0
# 15                   4

# %%
plt.scatter(data['Spending Score (1-100)'],data['Annual Income (k$)'], c= clusters['prediction'], cmap='rainbow')
plt.ylabel('Annual Income (k$)')
plt.xlabel('Spending Score (1-100)')
# Out:
# Text(0.5, 0, 'Spending Score (1-100)')

# %%
kmeans = KMeans(5)
kmeans.fit(data)
clusters = data.copy()
clusters['prediction'] = kmeans.fit_predict(data)
plt.scatter(data['Spending Score (1-100)'],data['Annual Income (k$)'], c= clusters['prediction'], cmap='rainbow')
plt.ylabel('Annual Income (k$)')
plt.xlabel('Spending Score (1-100)')
# Out:
# Text(0.5, 0, 'Spending Score (1-100)')

# %%
clusters.groupby('prediction').mean()
# Out:
#               Gender        Age  Annual Income (k$)  Spending Score (1-100)
# prediction
# 0           0.472222  40.666667           87.750000               17.583333
# 1           0.582278  43.088608           55.291139               49.569620
# 2           0.608696  25.521739           26.304348               78.565217
# 3           0.538462  32.692308           86.538462               82.128205
# 4           0.608696  45.217391           26.304348               20.913043

# %% [markdown]
# ### This divided the middle cluster into further parts which is not required so K=5 looks like the best option hence we'll stop here as k=5 is the best approach
